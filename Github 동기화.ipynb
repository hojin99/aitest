# %% [markdown]
# ### Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 대상 경로로 이동

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !rm -rf .ipynb_checkpoints
# !ls -al
# Out:
# total 0

# %%
# !git clone https://조호진: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@github.com/hojin99/aitest.git .
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), done.

# %% [markdown]
# ### Git 저장소 동기화

# %%
# !git add --all
# !git commit -m '수정'
# !git pull
# Out:
# [main 14dca68] 수정
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite "K\341\204\216\341\205\254\341\204\200\341\205\263\341\206\253\341\204\214\341\205\245\341\206\270,\341\204\211\341\205\245\341\206\253\341\204\222\341\205\247\341\206\274\341\204\222\341\205\254\341\204\200\341\205\261" (97%)
#  create mode 100644 Untitled0.ipynb
# Already up to date.

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ### Git 설정 확인

# %%
# !git config -l
# Out:
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://조호진: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@github.com/hojin99/aitest.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main
